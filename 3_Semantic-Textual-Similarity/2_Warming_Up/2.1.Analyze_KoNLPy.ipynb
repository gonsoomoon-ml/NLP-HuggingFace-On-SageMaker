# %% [markdown]
# # [모듈 9.1] KoNLPy Tokeninzer 비교
#
# 자연어의 "토큰" 분리를 위한 KoNLPy 에 대해서 확인하고, 적당한 Tokenizer 를 고르기 위해서 준비 했습니다.
#
# ---
# 참고 자료
# - [KoNLPy Tage Package](https://konlpy-ko.readthedocs.io/ko/v0.4.3/api/konlpy.tag/)

# %%
# raw = '지금 코로나판데막 상태라 기내 엔터테인먼트와 식사가 그 전과 비교시 좋지 않음'
# raw = '직원들의 노력과 친절에 감사합니다 다만 코로나19 사태에서 아무리 거리두기를 한다고는하나 그래도 친절하게 응대를 해주시길 한번 더 부탁드립니다'

raw = '주꾸미 오징어 문어 요런거 느므느므 좋아하는데 혼자 사는 싱글족이라 주꾸미 땡겨도 막상 근처에 갈데가 없고,볶음류가 은근 2인분 이상 주문해야되는곳도 많아서ㅠㅠ 요즘 한끼 먹기 좋게 포장된 주꾸미를 열심히 섭렵 중에 있답니닷! ^^ 한끼용이지만 마치 두끼인것처럼 든든하게 먹기 위해서 좋아하는거 맘껏 다 준비해서 만들었어요ㅎㅎㅎ 1. 중국식 넓적 당면 불려 두고 2. 함께 주문한 왕통통 새우도 넣고 3. 볶음류에 깻잎 또 필수 중에 필수죠ㅋㅋ 4. 거기다가 매운고추 더 뿌려서 5. 고소함 띠드 한장 싸악 올려서 먹음 채고!!! 채고!!! 오늘 받자마자 저녁으로 만들어 먹어보니 홍대주꾸미가 다른 주꾸미 보다 좋았던게 익는 순간 쪼그라 들면서 반토막나는데가 진짜 너무 많았거든요? ㅠㅠ 실망 실망 대실망ㅠㅠ 근데 여긴 사이즈가 변함없이 통통하니 쫄깃쫄깃 씹는 재미,식감을 즐기기도 너무 좋더라구요. >.< 딱 좋아요! 맘에 들었어요! 쟁여두고 사먹을 아이템으로 등극했어요~*^^*'

# %% [markdown]
# ## Twitter

# %%
from konlpy.tag import Twitter
twitter = Twitter()

print("sentence: \n", raw)
twitter.pos(
            raw, 
            norm=True,   # normalize 그랰ㅋㅋ -> 그래ㅋㅋ
            stem=True    # stemming 바뀌나->바뀌다
            )
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# sentence:
#  주꾸미 오징어 문어 요런거 느므느므 좋아하는데 혼자 사는 싱글족이라 주꾸미 땡겨도 막상 근처에 갈데가 없고,볶음류가 은근 2인분 이상 주문해야되는곳도 많아서ㅠㅠ 요즘 한끼 먹기 좋게 포장된 주꾸미를 열심히 섭렵 중에 있답니닷! ^^ 한끼용이지만 마치 두끼인것처럼 든든하게 먹기 위해서 좋아하는거 맘껏 다 준비해서 만들었어요ㅎㅎㅎ 1. 중국식 넓적 당면 불려 두고 2. 함께 주문한 왕통통 새우도 넣고 3. 볶음류에 깻잎 또 필수 중에 필수죠ㅋㅋ 4. 거기다가 매운고추 더 뿌려서 5. 고소함 띠드 한장 싸악 올려서 먹음 채고!!! 채고!!! 오늘 받자마자 저녁으로 만들어 먹어보니 홍대주꾸미가 다른 주꾸미 보다 좋았던게 익는 순간 쪼그라 들면서 반토막나는데가 진짜 너무 많았거든요? ㅠㅠ 실망 실망 대실망ㅠㅠ 근데 여긴 사이즈가 변함없이 통통하니 쫄깃쫄깃 씹는 재미,식감을 즐기기도 너무 좋더라구요. >.< 딱 좋아요! 맘에 들었어요! 쟁여두고 사먹을 아이템으로 등극했어요~*^^*
# [('주꾸미', 'Noun'),
#  ('오징어', 'Noun'),
#  ('문어', 'Noun'),
#  ('요런', 'Modifier'),
#  ('거', 'Noun'),
#  ('느므느므', 'Noun'),
#  ('좋아하다', 'Adjective'),
#  ('혼자', 'Noun'),
#  ('살다', 'Verb'),
#  ('싱글', 'Noun'),
#  ('족', 'Noun'),
#  ('이라', 'Josa'),
#  ('주꾸미', 'Noun'),
#  ('땡기다', 'Verb'),
#  ('막상', 'Noun'),
#  ('근처', 'Noun'),
#  ('에', 'Josa'),
#  ('갈다', 'Verb'),
#  ('없다', 'Adjective'),
#  (',', 'Punctuation'),
#  ('볶음', 'Noun'),
#  ('류', 'Noun'),
#  ('가', 'Josa'),
#  ('은근', 'Noun'),
#  ('2', 'Number'),
#  ('인분', 'Noun'),
#  ('이상', 'Noun'),
#  ('주문', 'Noun'),
#  ('하다', 'Verb'),
#  ('되다', 'Verb'),
#  ('곳도', 'Noun'),
#  ('많다', 'Adjective'),
#  ('ㅠㅠ', 'KoreanParticle'),
#  ('요즘', 'Noun'),
#  ('한', 'Determiner'),
#  ('끼', 'Noun'),
#  ('먹기', 'Noun'),
#  ('좋다', 'Adjective'),
#  ('포장', 'Noun'),
#  ('되다', 'Verb'),
#  ('주꾸미', 'Noun'),
#  ('를', 'Josa'),
#  ('열심히', 'Adverb'),
#  ('섭렵', 'Noun'),
#  ('중', 'Noun'),
#  ('에', 'Josa'),
#  ('있다', 'Adjective'),
#  ('닷', 'Noun'),
#  ('!', 'Punctuation'),
#  ('^^', 'Punctuation'),
#  ('한', 'Determiner'),
#  ('끼', 'Noun'),
#  ('용이', 'Noun'),
#  ('지만', 'Josa'),
#  ('마치', 'Noun'),
#  ('두', 'Determiner'),
#  ('끼', 'Noun'),
#  ('인', 'Josa'),
#  ('것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('든든하다', 'Adjective'),
#  ('먹기', 'Noun'),
#  ('위해', 'Noun'),
#  ('서', 'Josa'),
#  ('좋아하다', 'Adjective'),
#  ('맘껏', 'Noun'),
#  ('다', 'Adverb'),
#  ('준비', 'Noun'),
#  ('하다', 'Verb'),
#  ('만들다', 'Verb'),
#  ('ㅎㅎㅎ', 'KoreanParticle'),
#  ('1', 'Number'),
#  ('.', 'Punctuation'),
#  ('중국', 'Noun'),
#  ('식', 'Suffix'),
#  ('넓다', 'Adjective'),
#  ('적', 'Noun'),
#  ('당면', 'Noun'),
#  ('불다', 'Verb'),
#  ('두다', 'Verb'),
#  ('2', 'Number'),
#  ('.', 'Punctuation'),
#  ('함께', 'Adverb'),
#  ('주문', 'Noun'),
#  ('한', 'Josa'),
#  ('왕', 'Noun'),
#  ('통통', 'Noun'),
#  ('새우다', 'Verb'),
#  ('넣다', 'Verb'),
#  ('3', 'Number'),
#  ('.', 'Punctuation'),
#  ('볶음', 'Noun'),
#  ('류', 'Noun'),
#  ('에', 'Josa'),
#  ('깻잎', 'Noun'),
#  ('또', 'Noun'),
#  ('필수', 'Noun'),
#  ('중', 'Noun'),
#  ('에', 'Josa'),
#  ('필수', 'Noun'),
#  ('죠', 'Josa'),
#  ('ㅋㅋ', 'KoreanParticle'),
#  ('4', 'Number'),
#  ('.', 'Punctuation'),
#  ('거기', 'Noun'),
#  ('다가', 'Noun'),
#  ('맵다', 'Adjective'),
#  ('고추', 'Noun'),
#  ('더', 'Noun'),
#  ('뿌리다', 'Verb'),
#  ('5', 'Number'),
#  ('.', 'Punctuation'),
#  ('고소하다', 'Adjective'),
#  ('띠드', 'Noun'),
#  ('한장', 'Noun'),
#  ('싸다', 'Verb'),
#  ('악', 'Noun'),
#  ('올리다', 'Verb'),
#  ('먹음', 'Noun'),
#  ('채다', 'Verb'),
#  ('!!!', 'Punctuation'),
#  ('채다', 'Verb'),
#  ('!!!', 'Punctuation'),
#  ('오늘', 'Noun'),
#  ('받다', 'Verb'),
#  ('저녁', 'Noun'),
#  ('으로', 'Josa'),
#  ('만들다', 'Verb'),
#  ('먹다', 'Verb'),
#  ('보다', 'Verb'),
#  ('홍대', 'Noun'),
#  ('주꾸미', 'Noun'),
#  ('가', 'Josa'),
#  ('다른', 'Noun'),
#  ('주꾸미', 'Noun'),
#  ('보다', 'Verb'),
#  ('좋다', 'Adjective'),
#  ('익다', 'Verb'),
#  ('순간', 'Noun'),
#  ('쪼그', 'Noun'),
#  ('라', 'Josa'),
#  ('들다', 'Verb'),
#  ('반토막', 'Noun'),
#  ('나', 'Josa'),
#  ('늘다', 'Verb'),
#  ('진짜', 'Noun'),
#  ('너무', 'Adverb'),
#  ('많다', 'Adjective'),
#  ('?', 'Punctuation'),
#  ('ㅠㅠ', 'KoreanParticle'),
#  ('실망', 'Noun'),
#  ('실망', 'Noun'),
#  ('대', 'Modifier'),
#  ('실망', 'Noun'),
#  ('ㅠㅠ', 'KoreanParticle'),
#  ('근데', 'Adverb'),
#  ('여기다', 'Verb'),
#  ('사이즈', 'Noun'),
#  ('가', 'Josa'),
#  ('변하다', 'Adjective'),
#  ('없이', 'Adverb'),
#  ('통통하다', 'Adjective'),
#  ('쫄깃쫄깃', 'Noun'),
#  ('씹다', 'Verb'),
#  ('재미', 'Noun'),
#  (',', 'Punctuation'),
#  ('식감', 'Noun'),
#  ('을', 'Josa'),
#  ('즐기다', 'Verb'),
#  ('기도', 'Noun'),
#  ('너무', 'Adverb'),
#  ('좋다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('>.<', 'Punctuation'),
#  ('딱', 'Adverb'),
#  ('좋다', 'Adjective'),
#  ('!', 'Punctuation'),
#  ('맘', 'Noun'),
#  ('에', 'Josa'),
#  ('들다', 'Verb'),
#  ('!', 'Punctuation'),
#  ('쟁여두', 'Noun'),
#  ('고', 'Josa'),
#  ('사먹다', 'Verb'),
#  ('아이템', 'Noun'),
#  ('으로', 'Josa'),
#  ('등', 'Noun'),
#  ('극', 'Suffix'),
#  ('하다', 'Verb'),
#  ('~*^^*', 'Punctuation')]

# %%
stop_words = ['대한항공','있다']
def tokenizer(raw, pos=["Noun","Adjective"], stopword=stop_words):
    return [
        word for word, tag in twitter.pos(
            raw, 
            norm=True,   # normalize 그랰ㅋㅋ -> 그래ㅋㅋ
            stem=True    # stemming 바뀌나->바뀌다
            )
            if len(word) > 1 and tag in pos and word not in stopword
        ]


tokenizer(raw)
# Out:
# ['주꾸미',
#  '오징어',
#  '문어',
#  '느므느므',
#  '좋아하다',
#  '혼자',
#  '싱글',
#  '주꾸미',
#  '막상',
#  '근처',
#  '없다',
#  '볶음',
#  '은근',
#  '인분',
#  '이상',
#  '주문',
#  '곳도',
#  '많다',
#  '요즘',
#  '먹기',
#  '좋다',
#  '포장',
#  '주꾸미',
#  '섭렵',
#  '용이',
#  '마치',
#  '든든하다',
#  '먹기',
#  '위해',
#  '좋아하다',
#  '맘껏',
#  '준비',
#  '중국',
#  '넓다',
#  '당면',
#  '주문',
#  '통통',
#  '볶음',
#  '깻잎',
#  '필수',
#  '필수',
#  '거기',
#  '다가',
#  '맵다',
#  '고추',
#  '고소하다',
#  '띠드',
#  '한장',
#  '먹음',
#  '오늘',
#  '저녁',
#  '홍대',
#  '주꾸미',
#  '다른',
#  '주꾸미',
#  '좋다',
#  '순간',
#  '쪼그',
#  '반토막',
#  '진짜',
#  '많다',
#  '실망',
#  '실망',
#  '실망',
#  '사이즈',
#  '변하다',
#  '통통하다',
#  '쫄깃쫄깃',
#  '재미',
#  '식감',
#  '기도',
#  '좋다',
#  '좋다',
#  '쟁여두',
#  '아이템']

# %% [markdown]
# ## hannanum

# %%
from konlpy.tag import Hannanum 
hannanum = Hannanum()

print("sentence: \n", raw)
hannanum.pos(
            raw, flatten=True
            )
# Out:
# sentence:
#  주꾸미 오징어 문어 요런거 느므느므 좋아하는데 혼자 사는 싱글족이라 주꾸미 땡겨도 막상 근처에 갈데가 없고,볶음류가 은근 2인분 이상 주문해야되는곳도 많아서ㅠㅠ 요즘 한끼 먹기 좋게 포장된 주꾸미를 열심히 섭렵 중에 있답니닷! ^^ 한끼용이지만 마치 두끼인것처럼 든든하게 먹기 위해서 좋아하는거 맘껏 다 준비해서 만들었어요ㅎㅎㅎ 1. 중국식 넓적 당면 불려 두고 2. 함께 주문한 왕통통 새우도 넣고 3. 볶음류에 깻잎 또 필수 중에 필수죠ㅋㅋ 4. 거기다가 매운고추 더 뿌려서 5. 고소함 띠드 한장 싸악 올려서 먹음 채고!!! 채고!!! 오늘 받자마자 저녁으로 만들어 먹어보니 홍대주꾸미가 다른 주꾸미 보다 좋았던게 익는 순간 쪼그라 들면서 반토막나는데가 진짜 너무 많았거든요? ㅠㅠ 실망 실망 대실망ㅠㅠ 근데 여긴 사이즈가 변함없이 통통하니 쫄깃쫄깃 씹는 재미,식감을 즐기기도 너무 좋더라구요. >.< 딱 좋아요! 맘에 들었어요! 쟁여두고 사먹을 아이템으로 등극했어요~*^^*
# [('주꾸미', 'N'),
#  ('오징어', 'N'),
#  ('문어', 'N'),
#  ('요런거', 'N'),
#  ('느므느므', 'N'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('ㄴ데', 'E'),
#  ('혼자', 'M'),
#  ('사', 'P'),
#  ('는', 'E'),
#  ('싱글족', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('주꾸미', 'N'),
#  ('땡겨', 'N'),
#  ('도', 'J'),
#  ('막상', 'M'),
#  ('근처', 'N'),
#  ('에', 'J'),
#  ('가', 'P'),
#  ('ㄹ', 'E'),
#  ('데', 'N'),
#  ('가', 'J'),
#  ('없고,볶음류', 'N'),
#  ('가', 'J'),
#  ('은근', 'N'),
#  ('2', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('분', 'N'),
#  ('이상', 'N'),
#  ('주문해야되는곳', 'N'),
#  ('도', 'J'),
#  ('많아서ㅠㅠ', 'N'),
#  ('요즘', 'M'),
#  ('한끼', 'N'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('좋', 'P'),
#  ('게', 'E'),
#  ('포장', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('를', 'J'),
#  ('열심히', 'M'),
#  ('섭렵', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('있답니닷', 'N'),
#  ('!', 'S'),
#  ('^^', 'S'),
#  ('한끼용이지', 'N'),
#  ('만', 'J'),
#  ('마치', 'M'),
#  ('두끼', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('처럼', 'J'),
#  ('든든', 'N'),
#  ('하', 'X'),
#  ('게', 'E'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('위하', 'P'),
#  ('어서', 'E'),
#  ('좋아하는거', 'N'),
#  ('맘껏', 'M'),
#  ('다', 'M'),
#  ('준비해서', 'N'),
#  ('만들었어욯ㅎㅎ', 'N'),
#  ('1.', 'N'),
#  ('중국식', 'N'),
#  ('넓적', 'M'),
#  ('당면', 'N'),
#  ('불리', 'P'),
#  ('어', 'E'),
#  ('두', 'P'),
#  ('고', 'E'),
#  ('2.', 'N'),
#  ('함께', 'M'),
#  ('주문한', 'N'),
#  ('왕통통', 'N'),
#  ('새우', 'N'),
#  ('도', 'J'),
#  ('넣', 'P'),
#  ('고', 'E'),
#  ('3.', 'N'),
#  ('볶음류', 'N'),
#  ('에', 'J'),
#  ('깻잎', 'N'),
#  ('또', 'M'),
#  ('피', 'P'),
#  ('ㄹ', 'E'),
#  ('수', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('필수죸ㅋ', 'N'),
#  ('4.', 'N'),
#  ('거기', 'N'),
#  ('이', 'J'),
#  ('다가', 'E'),
#  ('매운고추', 'N'),
#  ('더', 'M'),
#  ('뿌리', 'P'),
#  ('어서', 'E'),
#  ('5.', 'N'),
#  ('고소함', 'N'),
#  ('띠드', 'N'),
#  ('한장', 'N'),
#  ('싸악', 'N'),
#  ('올리', 'P'),
#  ('어서', 'E'),
#  ('먹', 'P'),
#  ('음', 'E'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('오늘', 'N'),
#  ('받', 'P'),
#  ('자마자', 'E'),
#  ('저녁', 'N'),
#  ('으로', 'J'),
#  ('만들', 'P'),
#  ('어', 'E'),
#  ('먹', 'P'),
#  ('어', 'E'),
#  ('보', 'P'),
#  ('니', 'E'),
#  ('홍대주꾸미', 'N'),
#  ('가', 'J'),
#  ('다르', 'P'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('보다', 'M'),
#  ('좋', 'P'),
#  ('아ㄴ게', 'E'),
#  ('익', 'P'),
#  ('는', 'E'),
#  ('순간', 'N'),
#  ('쪼그', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('들', 'P'),
#  ('면서', 'E'),
#  ('반토막나는데', 'N'),
#  ('가', 'J'),
#  ('진짜', 'N'),
#  ('너무', 'M'),
#  ('많', 'P'),
#  ('아거든', 'E'),
#  ('요', 'J'),
#  ('?', 'S'),
#  ('ㅠㅠ', 'N'),
#  ('실망', 'N'),
#  ('실망', 'N'),
#  ('대실망ㅠㅠ', 'N'),
#  ('근데', 'N'),
#  ('여기', 'P'),
#  ('ㄴ', 'E'),
#  ('사이즈', 'N'),
#  ('가', 'J'),
#  ('변함없이', 'M'),
#  ('통통하', 'P'),
#  ('니', 'E'),
#  ('쫄깃쫄깃', 'N'),
#  ('씹', 'P'),
#  ('는', 'E'),
#  ('재미,식감', 'N'),
#  ('을', 'J'),
#  ('즐기', 'P'),
#  ('기', 'E'),
#  ('도', 'J'),
#  ('너무', 'M'),
#  ('좋', 'P'),
#  ('더라구', 'E'),
#  ('요', 'J'),
#  ('.', 'S'),
#  ('>.<', 'S'),
#  ('딱', 'M'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('말', 'P'),
#  ('ㅁ', 'E'),
#  ('에', 'J'),
#  ('들', 'P'),
#  ('었어', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('쟁여두', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('사먹', 'N'),
#  ('을', 'J'),
#  ('아이템', 'N'),
#  ('으로', 'J'),
#  ('등극', 'N'),
#  ('하', 'X'),
#  ('었어요', 'E'),
#  ('~*^^*', 'S')]

# %% [markdown]
# ## Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()

print("sentence: \n", raw)
hannanum.pos(
            raw, flatten=True
            )
# Out:
# sentence:
#  주꾸미 오징어 문어 요런거 느므느므 좋아하는데 혼자 사는 싱글족이라 주꾸미 땡겨도 막상 근처에 갈데가 없고,볶음류가 은근 2인분 이상 주문해야되는곳도 많아서ㅠㅠ 요즘 한끼 먹기 좋게 포장된 주꾸미를 열심히 섭렵 중에 있답니닷! ^^ 한끼용이지만 마치 두끼인것처럼 든든하게 먹기 위해서 좋아하는거 맘껏 다 준비해서 만들었어요ㅎㅎㅎ 1. 중국식 넓적 당면 불려 두고 2. 함께 주문한 왕통통 새우도 넣고 3. 볶음류에 깻잎 또 필수 중에 필수죠ㅋㅋ 4. 거기다가 매운고추 더 뿌려서 5. 고소함 띠드 한장 싸악 올려서 먹음 채고!!! 채고!!! 오늘 받자마자 저녁으로 만들어 먹어보니 홍대주꾸미가 다른 주꾸미 보다 좋았던게 익는 순간 쪼그라 들면서 반토막나는데가 진짜 너무 많았거든요? ㅠㅠ 실망 실망 대실망ㅠㅠ 근데 여긴 사이즈가 변함없이 통통하니 쫄깃쫄깃 씹는 재미,식감을 즐기기도 너무 좋더라구요. >.< 딱 좋아요! 맘에 들었어요! 쟁여두고 사먹을 아이템으로 등극했어요~*^^*
# [('주꾸미', 'N'),
#  ('오징어', 'N'),
#  ('문어', 'N'),
#  ('요런거', 'N'),
#  ('느므느므', 'N'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('ㄴ데', 'E'),
#  ('혼자', 'M'),
#  ('사', 'P'),
#  ('는', 'E'),
#  ('싱글족', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('주꾸미', 'N'),
#  ('땡겨', 'N'),
#  ('도', 'J'),
#  ('막상', 'M'),
#  ('근처', 'N'),
#  ('에', 'J'),
#  ('가', 'P'),
#  ('ㄹ', 'E'),
#  ('데', 'N'),
#  ('가', 'J'),
#  ('없고,볶음류', 'N'),
#  ('가', 'J'),
#  ('은근', 'N'),
#  ('2', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('분', 'N'),
#  ('이상', 'N'),
#  ('주문해야되는곳', 'N'),
#  ('도', 'J'),
#  ('많아서ㅠㅠ', 'N'),
#  ('요즘', 'M'),
#  ('한끼', 'N'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('좋', 'P'),
#  ('게', 'E'),
#  ('포장', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('를', 'J'),
#  ('열심히', 'M'),
#  ('섭렵', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('있답니닷', 'N'),
#  ('!', 'S'),
#  ('^^', 'S'),
#  ('한끼용이지', 'N'),
#  ('만', 'J'),
#  ('마치', 'M'),
#  ('두끼', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('처럼', 'J'),
#  ('든든', 'N'),
#  ('하', 'X'),
#  ('게', 'E'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('위하', 'P'),
#  ('어서', 'E'),
#  ('좋아하는거', 'N'),
#  ('맘껏', 'M'),
#  ('다', 'M'),
#  ('준비해서', 'N'),
#  ('만들었어욯ㅎㅎ', 'N'),
#  ('1.', 'N'),
#  ('중국식', 'N'),
#  ('넓적', 'M'),
#  ('당면', 'N'),
#  ('불리', 'P'),
#  ('어', 'E'),
#  ('두', 'P'),
#  ('고', 'E'),
#  ('2.', 'N'),
#  ('함께', 'M'),
#  ('주문한', 'N'),
#  ('왕통통', 'N'),
#  ('새우', 'N'),
#  ('도', 'J'),
#  ('넣', 'P'),
#  ('고', 'E'),
#  ('3.', 'N'),
#  ('볶음류', 'N'),
#  ('에', 'J'),
#  ('깻잎', 'N'),
#  ('또', 'M'),
#  ('피', 'P'),
#  ('ㄹ', 'E'),
#  ('수', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('필수죸ㅋ', 'N'),
#  ('4.', 'N'),
#  ('거기', 'N'),
#  ('이', 'J'),
#  ('다가', 'E'),
#  ('매운고추', 'N'),
#  ('더', 'M'),
#  ('뿌리', 'P'),
#  ('어서', 'E'),
#  ('5.', 'N'),
#  ('고소함', 'N'),
#  ('띠드', 'N'),
#  ('한장', 'N'),
#  ('싸악', 'N'),
#  ('올리', 'P'),
#  ('어서', 'E'),
#  ('먹', 'P'),
#  ('음', 'E'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('오늘', 'N'),
#  ('받', 'P'),
#  ('자마자', 'E'),
#  ('저녁', 'N'),
#  ('으로', 'J'),
#  ('만들', 'P'),
#  ('어', 'E'),
#  ('먹', 'P'),
#  ('어', 'E'),
#  ('보', 'P'),
#  ('니', 'E'),
#  ('홍대주꾸미', 'N'),
#  ('가', 'J'),
#  ('다르', 'P'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('보다', 'M'),
#  ('좋', 'P'),
#  ('아ㄴ게', 'E'),
#  ('익', 'P'),
#  ('는', 'E'),
#  ('순간', 'N'),
#  ('쪼그', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('들', 'P'),
#  ('면서', 'E'),
#  ('반토막나는데', 'N'),
#  ('가', 'J'),
#  ('진짜', 'N'),
#  ('너무', 'M'),
#  ('많', 'P'),
#  ('아거든', 'E'),
#  ('요', 'J'),
#  ('?', 'S'),
#  ('ㅠㅠ', 'N'),
#  ('실망', 'N'),
#  ('실망', 'N'),
#  ('대실망ㅠㅠ', 'N'),
#  ('근데', 'N'),
#  ('여기', 'P'),
#  ('ㄴ', 'E'),
#  ('사이즈', 'N'),
#  ('가', 'J'),
#  ('변함없이', 'M'),
#  ('통통하', 'P'),
#  ('니', 'E'),
#  ('쫄깃쫄깃', 'N'),
#  ('씹', 'P'),
#  ('는', 'E'),
#  ('재미,식감', 'N'),
#  ('을', 'J'),
#  ('즐기', 'P'),
#  ('기', 'E'),
#  ('도', 'J'),
#  ('너무', 'M'),
#  ('좋', 'P'),
#  ('더라구', 'E'),
#  ('요', 'J'),
#  ('.', 'S'),
#  ('>.<', 'S'),
#  ('딱', 'M'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('말', 'P'),
#  ('ㅁ', 'E'),
#  ('에', 'J'),
#  ('들', 'P'),
#  ('었어', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('쟁여두', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('사먹', 'N'),
#  ('을', 'J'),
#  ('아이템', 'N'),
#  ('으로', 'J'),
#  ('등극', 'N'),
#  ('하', 'X'),
#  ('었어요', 'E'),
#  ('~*^^*', 'S')]

# %% [markdown]
# ## Komoran

# %%
from konlpy.tag import Komoran
komoran = Komoran()

print("sentence: \n", raw)
hannanum.pos(
            raw, flatten=True
            )
# Out:
# sentence:
#  주꾸미 오징어 문어 요런거 느므느므 좋아하는데 혼자 사는 싱글족이라 주꾸미 땡겨도 막상 근처에 갈데가 없고,볶음류가 은근 2인분 이상 주문해야되는곳도 많아서ㅠㅠ 요즘 한끼 먹기 좋게 포장된 주꾸미를 열심히 섭렵 중에 있답니닷! ^^ 한끼용이지만 마치 두끼인것처럼 든든하게 먹기 위해서 좋아하는거 맘껏 다 준비해서 만들었어요ㅎㅎㅎ 1. 중국식 넓적 당면 불려 두고 2. 함께 주문한 왕통통 새우도 넣고 3. 볶음류에 깻잎 또 필수 중에 필수죠ㅋㅋ 4. 거기다가 매운고추 더 뿌려서 5. 고소함 띠드 한장 싸악 올려서 먹음 채고!!! 채고!!! 오늘 받자마자 저녁으로 만들어 먹어보니 홍대주꾸미가 다른 주꾸미 보다 좋았던게 익는 순간 쪼그라 들면서 반토막나는데가 진짜 너무 많았거든요? ㅠㅠ 실망 실망 대실망ㅠㅠ 근데 여긴 사이즈가 변함없이 통통하니 쫄깃쫄깃 씹는 재미,식감을 즐기기도 너무 좋더라구요. >.< 딱 좋아요! 맘에 들었어요! 쟁여두고 사먹을 아이템으로 등극했어요~*^^*
# [('주꾸미', 'N'),
#  ('오징어', 'N'),
#  ('문어', 'N'),
#  ('요런거', 'N'),
#  ('느므느므', 'N'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('하', 'P'),
#  ('ㄴ데', 'E'),
#  ('혼자', 'M'),
#  ('사', 'P'),
#  ('는', 'E'),
#  ('싱글족', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('주꾸미', 'N'),
#  ('땡겨', 'N'),
#  ('도', 'J'),
#  ('막상', 'M'),
#  ('근처', 'N'),
#  ('에', 'J'),
#  ('가', 'P'),
#  ('ㄹ', 'E'),
#  ('데', 'N'),
#  ('가', 'J'),
#  ('없고,볶음류', 'N'),
#  ('가', 'J'),
#  ('은근', 'N'),
#  ('2', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('분', 'N'),
#  ('이상', 'N'),
#  ('주문해야되는곳', 'N'),
#  ('도', 'J'),
#  ('많아서ㅠㅠ', 'N'),
#  ('요즘', 'M'),
#  ('한끼', 'N'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('좋', 'P'),
#  ('게', 'E'),
#  ('포장', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('를', 'J'),
#  ('열심히', 'M'),
#  ('섭렵', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('있답니닷', 'N'),
#  ('!', 'S'),
#  ('^^', 'S'),
#  ('한끼용이지', 'N'),
#  ('만', 'J'),
#  ('마치', 'M'),
#  ('두끼', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('처럼', 'J'),
#  ('든든', 'N'),
#  ('하', 'X'),
#  ('게', 'E'),
#  ('먹', 'P'),
#  ('기', 'E'),
#  ('위하', 'P'),
#  ('어서', 'E'),
#  ('좋아하는거', 'N'),
#  ('맘껏', 'M'),
#  ('다', 'M'),
#  ('준비해서', 'N'),
#  ('만들었어욯ㅎㅎ', 'N'),
#  ('1.', 'N'),
#  ('중국식', 'N'),
#  ('넓적', 'M'),
#  ('당면', 'N'),
#  ('불리', 'P'),
#  ('어', 'E'),
#  ('두', 'P'),
#  ('고', 'E'),
#  ('2.', 'N'),
#  ('함께', 'M'),
#  ('주문한', 'N'),
#  ('왕통통', 'N'),
#  ('새우', 'N'),
#  ('도', 'J'),
#  ('넣', 'P'),
#  ('고', 'E'),
#  ('3.', 'N'),
#  ('볶음류', 'N'),
#  ('에', 'J'),
#  ('깻잎', 'N'),
#  ('또', 'M'),
#  ('피', 'P'),
#  ('ㄹ', 'E'),
#  ('수', 'N'),
#  ('중', 'N'),
#  ('에', 'J'),
#  ('필수죸ㅋ', 'N'),
#  ('4.', 'N'),
#  ('거기', 'N'),
#  ('이', 'J'),
#  ('다가', 'E'),
#  ('매운고추', 'N'),
#  ('더', 'M'),
#  ('뿌리', 'P'),
#  ('어서', 'E'),
#  ('5.', 'N'),
#  ('고소함', 'N'),
#  ('띠드', 'N'),
#  ('한장', 'N'),
#  ('싸악', 'N'),
#  ('올리', 'P'),
#  ('어서', 'E'),
#  ('먹', 'P'),
#  ('음', 'E'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('채', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('!!!', 'S'),
#  ('오늘', 'N'),
#  ('받', 'P'),
#  ('자마자', 'E'),
#  ('저녁', 'N'),
#  ('으로', 'J'),
#  ('만들', 'P'),
#  ('어', 'E'),
#  ('먹', 'P'),
#  ('어', 'E'),
#  ('보', 'P'),
#  ('니', 'E'),
#  ('홍대주꾸미', 'N'),
#  ('가', 'J'),
#  ('다르', 'P'),
#  ('ㄴ', 'E'),
#  ('주꾸미', 'N'),
#  ('보다', 'M'),
#  ('좋', 'P'),
#  ('아ㄴ게', 'E'),
#  ('익', 'P'),
#  ('는', 'E'),
#  ('순간', 'N'),
#  ('쪼그', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('들', 'P'),
#  ('면서', 'E'),
#  ('반토막나는데', 'N'),
#  ('가', 'J'),
#  ('진짜', 'N'),
#  ('너무', 'M'),
#  ('많', 'P'),
#  ('아거든', 'E'),
#  ('요', 'J'),
#  ('?', 'S'),
#  ('ㅠㅠ', 'N'),
#  ('실망', 'N'),
#  ('실망', 'N'),
#  ('대실망ㅠㅠ', 'N'),
#  ('근데', 'N'),
#  ('여기', 'P'),
#  ('ㄴ', 'E'),
#  ('사이즈', 'N'),
#  ('가', 'J'),
#  ('변함없이', 'M'),
#  ('통통하', 'P'),
#  ('니', 'E'),
#  ('쫄깃쫄깃', 'N'),
#  ('씹', 'P'),
#  ('는', 'E'),
#  ('재미,식감', 'N'),
#  ('을', 'J'),
#  ('즐기', 'P'),
#  ('기', 'E'),
#  ('도', 'J'),
#  ('너무', 'M'),
#  ('좋', 'P'),
#  ('더라구', 'E'),
#  ('요', 'J'),
#  ('.', 'S'),
#  ('>.<', 'S'),
#  ('딱', 'M'),
#  ('좋', 'P'),
#  ('아', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('말', 'P'),
#  ('ㅁ', 'E'),
#  ('에', 'J'),
#  ('들', 'P'),
#  ('었어', 'E'),
#  ('요', 'J'),
#  ('!', 'S'),
#  ('쟁여두', 'N'),
#  ('이', 'J'),
#  ('고', 'E'),
#  ('사먹', 'N'),
#  ('을', 'J'),
#  ('아이템', 'N'),
#  ('으로', 'J'),
#  ('등극', 'N'),
#  ('하', 'X'),
#  ('었어요', 'E'),
#  ('~*^^*', 'S')]
